# %%
import pandas as pd

# %%
import numpy as np
import statsmodels.api as sm
from matplotlib.pyplot import subplots as sp

# %%
from statsmodels.stats.outliers_influence \
     import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm

# %%
# !conda create --name islp_env
# !conda activate islp
# !pip install ISLP
# Out:
# Jupyter detected...
# CondaToSNonInteractiveError: Terms of Service have not been accepted for the following channels. Please accept or remove them before proceeding:
#     • https://repo.anaconda.com/pkgs/r
#     • https://repo.anaconda.com/pkgs/msys2
#
# To accept a channel's Terms of Service, run the following and replace `CHANNEL` with the channel name/URL:
#     \u2023 conda tos accept --override-channels --channel CHANNEL
#
# To remove channels with rejected Terms of Service, run the following and replace `CHANNEL` with the channel name/URL:
#     \u2023 conda config --remove channels CHANNEL
# Failed to run 'conda activate islp'.
# EnvironmentNameNotFound: Could not find conda environment: islp
# You can list all discoverable environments with `conda info --envs`.
# ...

# %%
from ISLP import load_data
from ISLP.models import (ModelSpec as MS, summarize, poly)

# %%
dir()
# Out:
# ['In',
#  'MS',
#  'Out',
#  'VIF',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'anova_lm',
#  'exit',
#  'get_ipython',
#  'load_data',
#  'np',
#  'open',
#  'pd',
#  'poly',
#  'quit',
#  'sm',
#  'sp',
#  'summarize']

# %%
A = np.array([1,9,0,5,4,7,3])
dir(A)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_namespace__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__buffer__',
#  '__class__',
#  '__class_getitem__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__dlpack__',
#  '__dlpack_device__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
# ...

# %%
A.sum()
# Out:
# np.int64(29)

# %%
Boston=load_data("Boston")
Boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
X = pd.DataFrame({'intercept':np.ones(Boston.shape[0]),
                 'lstat': Boston['lstat']})
X[:4]
# Out:
#    intercept  lstat
# 0        1.0   4.98
# 1        1.0   9.14
# 2        1.0   4.03
# 3        1.0   2.94

# %%
y=Boston['medv']
model=sm.OLS(y,X)
results=model.fit()

# %%
summarize(results)
# Out:
#               coef  std err       t  P>|t|
# intercept  34.5538    0.563  61.415    0.0
# lstat      -0.9500    0.039 -24.528    0.0

# %%
design = MS(['lstat'])
design = design.fit(Boston)
X = design.fit_transform(Boston)
X
# Out:
#      intercept  lstat
# 0          1.0   4.98
# 1          1.0   9.14
# 2          1.0   4.03
# 3          1.0   2.94
# 4          1.0   5.33
# ..         ...    ...
# 501        1.0   9.67
# 502        1.0   9.08
# 503        1.0   5.64
# 504        1.0   6.48
# 505        1.0   7.88
#
# [506 rows x 2 columns]

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     601.6
# Date:                Sun, 24 Aug 2025   Prob (F-statistic):           5.08e-88
# Time:                        21:41:57   Log-Likelihood:                -1641.5
# No. Observations:                 506   AIC:                             3287.
# Df Residuals:                     504   BIC:                             3295.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     34.5538      0.563     61.415      0.000      33.448      35.659
# ...

# %%
results.params
# Out:
# intercept    34.553841
# lstat        -0.950049
# dtype: float64

# %%
newDf = pd.DataFrame({'lstat':[5,10,15]})
newX = design.fit_transform(newDf)
newX
# Out:
#    intercept  lstat
# 0        1.0      5
# 1        1.0     10
# 2        1.0     15

# %%
newPred = results.get_prediction(newX);
newPred.predicted_mean
# Out:
# array([29.80359411, 25.05334734, 20.30310057])

# %%
newPred.conf_int(alpha=0.05)
# Out:
# array([[29.00741194, 30.59977628],
#        [24.47413202, 25.63256267],
#        [19.73158815, 20.87461299]])

# %%
newPred.conf_int(obs=True, alpha=0.05)
# Out:
# array([[17.56567478, 42.04151344],
#        [12.82762635, 37.27906833],
#        [ 8.0777421 , 32.52845905]])

# %%
def LineAb (ax, c, m):
    "Add a line with slope m and intercept c to ax"
    xlim = ax.get_xlim()
    ylim = [m * xlim[0] + c,  m * xlimm[1] + c]
    ax.plot(xlim, ylim)

# %%
def LineAb (ax, c, m, *args, **kwargs):
    "Add a line with slope m and intercept c to ax"
    xlim = ax.get_xlim()
    ylim = [m * xlim[0] + c,  m * xlim[1] + c]
    ax.plot(xlim, ylim, *args, **kwargs)

# %%
ax = Boston.plot.scatter('medv', 'lstat')
LineAb(ax,
      results.params[0],
      results.params[1],
      'r--',
      linewidth=4)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7244\3278713224.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.params[0],
# C:\Users\hp\AppData\Local\Temp\ipykernel_7244\3278713224.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.params[1],

# %%
ax = sp(figsize=(12,8))[1]
ax.scatter(results.fittedvalues, results.resid)
ax.set_xlabel('Fitted Value')
ax.set_ylabel('Residual')
ax.axhline(0, c='k', ls='--');

# %%
infl = results.get_influence()
ax = sp(figsize=(12,8))[1]
ax.scatter(np.arange(X.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')
np.argmax(infl.hat_matrix_diag)
# Out:
# np.int64(374)

# %%
X = MS (['lstat', 'age']).fit_transform(Boston)
model1 = sm.OLS(y, X)
results1 = model1.fit()
summarize(results1)
# Out:
#               coef  std err       t  P>|t|
# intercept  33.2228    0.731  45.458  0.000
# lstat      -1.0321    0.048 -21.416  0.000
# age         0.0345    0.012   2.826  0.005

# %%
terms = Boston.columns.drop('medv')
terms
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat'],
#       dtype='object')

# %%
X = MS(terms).fit_transform(Boston)
model = sm.OLS(y,X)
results = model.fit()
summarize(results)
# Out:
#               coef  std err       t  P>|t|
# intercept  41.6173    4.936   8.431  0.000
# crim       -0.1214    0.033  -3.678  0.000
# zn          0.0470    0.014   3.384  0.001
# indus       0.0135    0.062   0.217  0.829
# chas        2.8400    0.870   3.264  0.001
# nox       -18.7580    3.851  -4.870  0.000
# rm          3.6581    0.420   8.705  0.000
# age         0.0036    0.013   0.271  0.787
# dis        -1.4908    0.202  -7.394  0.000
# rad         0.2894    0.067   4.325  0.000
# tax        -0.0127    0.004  -3.337  0.001
# ptratio    -0.9375    0.132  -7.091  0.000
# lstat      -0.5520    0.051 -10.897  0.000

# %%
vals = [VIF(X, i)
       for  i in range(1, X.shape[1])]
vif = pd.DataFrame({'vif':vals},
                  index = X.columns[1:])
vif
# Out:
#               vif
# crim     1.767486
# zn       2.298459
# indus    3.987181
# chas     1.071168
# nox      4.369093
# rm       1.912532
# age      3.088232
# dis      3.954037
# rad      7.445301
# tax      9.002158
# ptratio  1.797060
# lstat    2.870777

# %%
X = MS (['lstat',
        'age',
         ('lstat', 'age')]).fit_transform(Boston)
model2 = sm.OLS(y,X)
summarize(model2.fit())
# Out:
#               coef  std err       t  P>|t|
# intercept  36.0885    1.470  24.553  0.000
# lstat      -1.3921    0.167  -8.313  0.000
# age        -0.0007    0.020  -0.036  0.971
# lstat:age   0.0042    0.002   2.244  0.025

# %%
X = MS([poly('lstat', degree=2), 'age']).fit_transform(Boston)
model3 = sm.OLS(y,X)
results3 = model3.fit()
summarize(results3)
# Out:
#                               coef  std err       t  P>|t|
# intercept                  17.7151    0.781  22.681    0.0
# poly(lstat, degree=2)[0] -179.2279    6.733 -26.620    0.0
# poly(lstat, degree=2)[1]   72.9908    5.482  13.315    0.0
# age                         0.0703    0.011   6.471    0.0

# %%
anova_lm(results1, results3)
# Out:
#    df_resid           ssr  df_diff      ss_diff           F        Pr(>F)
# 0     503.0  19168.128609      0.0          NaN         NaN           NaN
# 1     502.0  14165.613251      1.0  5002.515357  177.278785  7.468491e-35

# %%
ax = sp(figsize=(12,8))[1]
ax.scatter(results3.fittedvalues, results3.resid)
ax.set_xlabel('Fitted Value')
ax.set_ylabel('Residual')
ax.axhline(0, c='k', ls='--')

# %%
carseats = load_data('Carseats')
carseats.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'ShelveLoc', 'Age', 'Education', 'Urban', 'US'],
#       dtype='object')

# %%
allvars = list(carseats.columns.drop('Sales'))
y = carseats['Sales']
final = allvars + [('Income', 'Advertising'),
                  ('Price', 'Age')]
X= MS(final).fit_transform(carseats)
model = sm.OLS(y,X)
summarize(model.fit())
# Out:
#                       coef  std err       t  P>|t|
# intercept           6.5756    1.009   6.519  0.000
# CompPrice           0.0929    0.004  22.567  0.000
# Income              0.0109    0.003   4.183  0.000
# Advertising         0.0702    0.023   3.107  0.002
# Population          0.0002    0.000   0.433  0.665
# Price              -0.1008    0.007 -13.549  0.000
# ShelveLoc[Good]     4.8487    0.153  31.724  0.000
# ShelveLoc[Medium]   1.9533    0.126  15.531  0.000
# Age                -0.0579    0.016  -3.633  0.000
# Education          -0.0209    0.020  -1.063  0.288
# Urban[Yes]          0.1402    0.112   1.247  0.213
# US[Yes]            -0.1576    0.149  -1.058  0.291
# Income:Advertising  0.0008    0.000   2.698  0.007
# Price:Age           0.0001    0.000   0.801  0.424
